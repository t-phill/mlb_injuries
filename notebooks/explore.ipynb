# %%
import pandas as pd
import numpy as np
import pickle
import datetime
from pybaseball import *
import sys
from datetime import datetime

from sqlalchemy import create_engine

# %%
import psycopg2
import pandas.io.sql as psql

from pybaseball import playerid_lookup
from pybaseball import pitching_stats_range

# %%
conn = psycopg2.connect(dbname='pitches_2018', user='taylorphillips', host='localhost')

# %%
cur = conn.cursor()

# %%
# test = psql.read_sql('''
# SELECT player_name, pitch_type, game_date as date, AVG(release_speed) as release_speed, AVG(release_spin_rate) as spin_rate, AVG(release_pos_x) as avg_x, AVG(release_pos_y) as avg_y, AVG(release_pos_z) as avg_z, pitcher FROM pitches 
# WHERE pitcher = {} 
# GROUP BY pitch_type, game_date, pitcher, player_name
# ORDER BY game_date
# '''.format(279571.0), conn)

# %%
test = psql.read_sql('''
SELECT player_name, game_date as date
FROM pitches
WHERE pitcher = {} 
GROUP BY game_date, pitcher, player_name
ORDER BY game_date
'''.format(279571.0), conn)

# %%
# playerid_lookup('verlander')

# %%
test
# Out:
#      player_name       date
# 0   Matt Belisle 2018-04-02
# 1   Matt Belisle 2018-04-03
# 2   Matt Belisle 2018-04-12
# 3   Matt Belisle 2018-04-13
# 4   Matt Belisle 2018-04-24
# 5   Matt Belisle 2018-04-28
# 6   Matt Belisle 2018-05-01
# 7   Matt Belisle 2018-06-13
# 8   Matt Belisle 2018-06-16
# 9   Matt Belisle 2018-06-17
# 10  Matt Belisle 2018-06-21
# 11  Matt Belisle 2018-06-22
# 12  Matt Belisle 2018-06-26
# 13  Matt Belisle 2018-06-29
# 14  Matt Belisle 2018-06-30
# 15  Matt Belisle 2018-07-06
# 16  Matt Belisle 2018-07-08
# 17  Matt Belisle 2018-07-10
# 18  Matt Belisle 2018-07-13
# 19  Matt Belisle 2018-07-14
# 20  Matt Belisle 2018-07-20
# 21  Matt Belisle 2018-07-23
# 22  Matt Belisle 2018-07-25
# 23  Matt Belisle 2018-07-27
# 24  Matt Belisle 2018-07-31
# 25  Matt Belisle 2018-08-06
# 26  Matt Belisle 2018-09-02
# 27  Matt Belisle 2018-09-05
# 28  Matt Belisle 2018-09-15
# 29  Matt Belisle 2018-09-26
# 30  Matt Belisle 2018-09-29
# 31  Matt Belisle 2018-09-30

# %%
srch = statcast('2018-04-18', '2018-04-18')

# %%
srch[srch['pitcher'] == 279571.0]
# Out:
#       index pitch_type  game_date  release_speed  release_pos_x  \
# 2501    245        NaN 2018-04-18            NaN            NaN
# 2502    247        NaN 2018-04-18            NaN            NaN
# 2503    249        NaN 2018-04-18            NaN            NaN
# 2504    251        NaN 2018-04-18            NaN            NaN
# 2505    253        NaN 2018-04-18            NaN            NaN
# 2506    255        NaN 2018-04-18            NaN            NaN
# 2507    257        NaN 2018-04-18            NaN            NaN
# 2508    259        NaN 2018-04-18            NaN            NaN
# 2509    261        NaN 2018-04-18            NaN            NaN
# 2510    262        NaN 2018-04-18            NaN            NaN
# 2511    265        NaN 2018-04-18            NaN            NaN
# 2512    267        NaN 2018-04-18            NaN            NaN
# 2513    269        NaN 2018-04-18            NaN            NaN
#
#       release_pos_z   player_name    batter   pitcher     events  \
# ...

# %%
# statcast_pitcher(player_id=279571.0)
# Out:
# ...
# Gathering Player Data
#                                                error
# 0  Error: Query Timeout. Please try to limit your...

# %%
pd.set_option('display.max_columns', 500)
test = test[test['date'] < '2018-10-01']
test
# Out:
#      player_name       date
# 0   Matt Belisle 2018-04-02
# 1   Matt Belisle 2018-04-03
# 2   Matt Belisle 2018-04-12
# 3   Matt Belisle 2018-04-13
# 4   Matt Belisle 2018-04-24
# 5   Matt Belisle 2018-04-28
# 6   Matt Belisle 2018-05-01
# 7   Matt Belisle 2018-06-13
# 8   Matt Belisle 2018-06-16
# 9   Matt Belisle 2018-06-17
# 10  Matt Belisle 2018-06-21
# 11  Matt Belisle 2018-06-22
# 12  Matt Belisle 2018-06-26
# 13  Matt Belisle 2018-06-29
# 14  Matt Belisle 2018-06-30
# 15  Matt Belisle 2018-07-06
# 16  Matt Belisle 2018-07-08
# 17  Matt Belisle 2018-07-10
# 18  Matt Belisle 2018-07-13
# 19  Matt Belisle 2018-07-14
# 20  Matt Belisle 2018-07-20
# 21  Matt Belisle 2018-07-23
# 22  Matt Belisle 2018-07-25
# 23  Matt Belisle 2018-07-27
# 24  Matt Belisle 2018-07-31
# 25  Matt Belisle 2018-08-06
# 26  Matt Belisle 2018-09-02
# 27  Matt Belisle 2018-09-05
# 28  Matt Belisle 2018-09-15
# 29  Matt Belisle 2018-09-26
# 30  Matt Belisle 2018-09-29
# 31  Matt Belisle 2018-09-30

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151 entries, 0 to 150
# Data columns (total 8 columns):
# player_name      151 non-null object
# pitch_type       149 non-null object
# game_date        151 non-null object
# release_speed    150 non-null float64
# avg_x            149 non-null float64
# avg_y            149 non-null float64
# avg_z            149 non-null float64
# pitcher          151 non-null float64
# dtypes: float64(5), object(3)
# memory usage: 9.5+ KB

# %%
pitch_type, game_date, release_speed, release_pos_x, release_pos_y, release_pos_z, player_name, pitcher
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-379e24c934fc> in <module>
# ----> 1 pitch_type, game_date, release_speed, release_pos_x, release_pos_y, release_pos_z, player_name, pitcher
#
# NameError: name 'pitch_type' is not defined

# %%
# season = psql.read_sql('''
# SELECT player_name, pitch_type, count(pitch_type) as count, AVG(release_spin_rate) as spin_rate, MAX(release_speed) as release_speed, AVG(release_extension) as extension, AVG(release_pos_x) as avg_x, AVG(release_pos_y) as avg_y, AVG(release_pos_z) as avg_z, pitcher FROM pitches 
# WHERE pitcher = 434378
# GROUP BY pitch_type, pitcher, player_name
# ''', conn)

# %%
season = psql.read_sql('''
SELECT pitch_name, pitch_type, p_throws, count(pitch_type) as count, AVG(release_spin_rate) as spin_rate, MAX(release_speed) as release_speed, MAX(effective_speed) as percieved_speed, AVG(release_extension) as extension, AVG(release_pos_x) as avg_x, AVG(release_pos_z) as avg_z, AVG(pfx_x) as x_movement, AVG(pfx_z) as z_movement FROM pitches 
GROUP BY pitch_name, pitch_type, p_throws
ORDER BY release_speed DESC
''', conn)

# %%
season
# Out:
#          pitch_name pitch_type p_throws   count    spin_rate  release_speed  \
# 0            Sinker         SI        R   34996  2112.801218          105.0
# 1            Sinker         SI        L   25144  2137.991367          104.4
# 2   4-Seam Fastball         FF        R  190177  2276.510016          104.0
# 3   4-Seam Fastball         FF        L   66936  2234.296123          103.6
# 4   2-Seam Fastball         FT        R   60544  2163.065661          102.3
# 5   2-Seam Fastball         FT        L   20698  2123.574252          101.9
# 6         Pitch Out         PO        R      87  2119.321839           97.3
# 7            Cutter         FC        R   26897  2396.986933           97.3
# 8            Slider         SL        R   93349  2416.420372           95.7
# 9            Cutter         FC        L   13649  2248.647570           94.6
# 10     Split Finger         FS        R    9353  1432.383751           94.4
# ...

# %%
season['pitch_type'].unique().tolist()
# Out:
# ['SI',
#  'FF',
#  'FT',
#  'PO',
#  'FC',
#  'SL',
#  'FS',
#  'CH',
#  'KC',
#  'CU',
#  'FO',
#  'KN',
#  'SC',
#  'EP']

# %%
average_pitcher_2018 = psql.read_sql('''
SELECT pitch_type, p_throws, count(pitch_type) as count, AVG(release_spin_rate) as spin_rate, AVG(release_speed) as release_speed, AVG(release_extension) as extension, AVG(release_pos_x) as avg_x, AVG(release_pos_y) as avg_y, AVG(release_pos_z) as avg_z FROM pitches 
GROUP BY pitch_type, p_throws
''', conn)

# %%
average_pitcher_2018
# Out:
#    pitch_type p_throws   count    spin_rate  release_speed  extension  \
# 0          CH        L   26395  1819.150127      83.282177   6.019335
# 1          CH        R   48874  1750.182893      84.724572   6.094948
# 2          CU        L   19272  2447.406608      76.541386   5.585409
# 3          CU        R   41725  2516.717571      79.074289   5.685648
# 4          EP        L       1  1860.000000      63.800000   5.847000
# 5          EP        R     204  2405.475490      67.605882   5.941240
# 6          FC        L   13563  2248.491404      87.388991   5.944998
# 7          FC        R   26748  2397.495237      89.358389   5.940045
# 8          FF        L   67499  2231.193787      92.246403   6.102959
# 9          FF        R  190125  2276.516920      93.520178   6.171951
# 10         FO        R      84  1677.253012      86.336905   5.128119
# 11         FS        L    1189  1365.306228      83.877881   5.568595
# ...

# %%
average_player.sum()
# Out:
# count            726455.000000
# release_speed      2252.584046
# avg_x                 2.640376
# avg_y              1475.726399
# avg_z               158.950073
# dtype: float64

# %%
errors = pd.read_pickle('errors.pkl')

# %%
len(errors)
# Out:
# 3697

# %%
b= psql.read_sql('''
SELECT * from pitches
ORDER BY pitcher, game_date
''', conn)

# %%
len(b)
# Out:
# 730136

# %%
len(b) - len(errors)
# Out:
# 726439

# %%
b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730136 entries, 0 to 730135
# Data columns (total 90 columns):
# index                              730136 non-null int64
# at_bat_number                      730135 non-null float64
# away_score                         730135 non-null float64
# away_team                          730135 non-null object
# ax                                 726317 non-null float64
# ay                                 726317 non-null float64
# az                                 726317 non-null float64
# babip_value                        186889 non-null float64
# balls                              730135 non-null float64
# bat_score                          730135 non-null float64
# batter                             730135 non-null float64
# bb_type                            127769 non-null object
# break_angle_deprecated             0 non-null object
# break_length_deprecated            0 non-null object
# ...

# %%
from pybaseball import pitching_stats_range

# %%
data = pitching_stats_range("2018-05-01", "2018-05-31")

# %%
data
# Out:
#                   Name  Age  #days     Lev             Tm   G  GS    W    L  \
# 1           Jason Adam   26    307  MLB-AL    Kansas City   8   0  NaN  NaN
# 2          Matt Albers   35    308  MLB-NL      Milwaukee   9   0  1.0  NaN
# 3      Scott Alexander   28    307  MLB-NL    Los Angeles   9   1  NaN  NaN
# 4           Cody Allen   29    305  MLB-AL      Cleveland  12   0  NaN  1.0
# 5        Dan Altavilla   25    306  MLB-AL        Seattle   7   0  1.0  NaN
# 6        Jose Alvarado   23    308  MLB-AL      Tampa Bay   8   0  NaN  NaN
# 7         Jose Alvarez   29    307  MLB-AL    Los Angeles  11   0  1.0  1.0
# 8       Brett Anderson   30    318  MLB-AL        Oakland   4   4  NaN  2.0
# 9       Chase Anderson   30    310  MLB-NL      Milwaukee   4   4  2.0  1.0
# 10     Justin Anderson   25    305  MLB-AL    Los Angeles  12   0  1.0  1.0
# 11      Tyler Anderson   28    310  MLB-NL       Colorado   5   5  2.0  1.0
# ...

# %%
data[data['Name'] == 'Justin Verlander']
# Out:
#                  Name  Age  #days     Lev       Tm  G  GS    W    L  SV    IP  \
# 502  Justin Verlander   35    308  MLB-AL  Houston  6   6  3.0  2.0 NaN  41.2
#
#       H  R  ER  BB  SO  HR  HBP   ERA   AB  2B  3B  IBB  GDP  SF  SB  CS  PO  \
# 502  22  5   4   7  50   1    2  0.86  144   5   2    0    0   1   0   0   1
#
#       BF  Pit   Str  StL   StS  GB/FB   LD    PU   WHIP  BAbip   SO9  SO/W
# 502  155  634  0.68  0.2  0.13   0.29  0.2  0.14  0.696  0.223  10.8  7.14

# %%
from pybaseball import pitching_stats_bref
from pybaseball import pitching_stats

# %%
sn = pitching_stats_bref(2018)

# %%
snst = pitching_stats(2018, qual=0)

# %%
snst
# Out:
#      Season                 Name          Team   Age     W     L    ERA  WAR  \
# 48   2018.0         Jacob deGrom          Mets  30.0  10.0   9.0   1.70  9.0
# 99   2018.0         Max Scherzer     Nationals  33.0  18.0   7.0   2.53  7.4
# 98   2018.0     Justin Verlander        Astros  35.0  16.0   9.0   2.52  6.7
# 64   2018.0           Chris Sale       Red Sox  29.0  12.0   4.0   2.11  6.2
# 140  2018.0          Gerrit Cole        Astros  27.0  15.0   5.0   2.88  6.0
# 179  2018.0       Patrick Corbin  Diamondbacks  28.0  11.0   7.0   3.15  5.9
# 71   2018.0         Trevor Bauer       Indians  27.0  12.0   6.0   2.21  5.8
# 143  2018.0         Corey Kluber       Indians  32.0  20.0   7.0   2.89  5.5
# 224  2018.0        Luis Severino       Yankees  24.0  19.0   8.0   3.39  5.5
# 81   2018.0           Aaron Nola      Phillies  25.0  17.0   6.0   2.37  5.4
# 221  2018.0      Carlos Carrasco       Indians  31.0  17.0  10.0   3.38  5.2
# ...

# %%
sn
# Out:
#                    Name  Age  #days            Lev                    Tm   G  \
# 1            Jason Adam   26    227         MLB-AL           Kansas City  31
# 2          Austin Adams   27    338         MLB-NL            Washington   2
# 3          Chance Adams   23    183         MLB-AL              New York   3
# 4           Matt Albers   35    190         MLB-NL             Milwaukee  34
# 5       Sandy Alcantara   22    183         MLB-NL                 Miami   6
# 6      Victor Alcantara   25    185         MLB-AL               Detroit  27
# 7       Scott Alexander   28    182         MLB-NL           Los Angeles  73
# 8          Kolby Allard   20    227         MLB-NL               Atlanta   3
# 9            Cody Allen   29    184         MLB-AL             Cleveland  70
# 10       Miguel Almonte   25    184         MLB-AL           Los Angeles   8
# 11        Yency Almonte   24    188         MLB-NL              Colorado  14
# ...

# %%
big = pitching_stats_range("2015-03-01", "2018-11-01")
big
# Out:
#                        Name  Age  #days            Lev  \
# 1             David Aardsma   33   1318         MLB-NL
# 2             Fernando Abad   31    548         MLB-AL
# 3               A.J. Achter   27    913         MLB-AL
# 4                Jason Adam   26    228         MLB-AL
# 5              Austin Adams   29    917         MLB-AL
# 6              Austin Adams   27    339         MLB-NL
# 7              Chance Adams   23    184         MLB-AL
# 8             Nathan Adcock   27   1346         MLB-NL
# 9               Tim Adleman   29    560         MLB-NL
# 10           Jeremy Affeldt   36   1276         MLB-NL
# 11            Andrew Albers   31    549         MLB-AL
# 12              Matt Albers   35    191  MLB-NL,MLB-AL
# 13          Al Alburquerque   31    549         MLB-AL
# 14           Raul Alcantara   24    550         MLB-AL
# 15          Sandy Alcantara   22    184         MLB-NL
# 16         Victor Alcantara   25    186         MLB-AL
# ...

# %%
# big.to_pickle('./sum_pitchers.pkl')

# %%
one = pitching_stats_range("2015-03-01", "2015-11-01")

# %%
two = pitching_stats_range("2016-03-01", "2016-11-01")

# %%
three = pitching_stats_range("2017-03-01", "2017-11-01")

# %%
four = pitching_stats_range("2018-03-01", "2018-11-01")

# %%
len(one) + len(two) + len(three) + len(four)
# Out:
# 3031

# %%
big.sum()
# Out:
# Name     David AardsmaFernando AbadA.J. AchterJason Ada...
# Age                                                  37689
# #days                                               675733
# Lev      MLB-NLMLB-ALMLB-ALMLB-ALMLB-ALMLB-NLMLB-ALMLB-...
# Tm       AtlantaBoston,Minnesota,OaklandLos Angeles,Min...
# G                                                    81826
# GS                                                   19436
# W                                                     9717
# L                                                     9717
# SV                                                    4991
# IP                                                  173188
# H                                                   167615
# R                                                    86600
# ER                                                   80264
# BB                                                   60675
# SO                                                  157739
# ...

# %%
x = pd.concat([one, two, three, four])

# %%
x.sum()
# Out:
# Name     David AardsmaFernando AbadA.J. AchterAustin Ad...
# Age                                                  84429
# #days                                              2257547
# Lev      MLB-NLMLB-ALMLB-ALMLB-ALMLB-NLMLB-NLMLB-ALMLB-...
# Tm       AtlantaOaklandMinnesotaClevelandCincinnatiSan ...
# G                                                    81826
# GS                                                   19436
# W                                                     9717
# L                                                     9717
# SV                                                    4991
# IP                                                  172813
# H                                                   167615
# R                                                    86600
# ER                                                   80264
# BB                                                   60675
# SO                                                  157739
# ...

# %%
big
# Out:
#                        Name  Age  #days            Lev  \
# 1             David Aardsma   33   1317         MLB-NL
# 2             Fernando Abad   31    547         MLB-AL
# 3               A.J. Achter   27    912         MLB-AL
# 4                Jason Adam   26    227         MLB-AL
# 5              Austin Adams   29    916         MLB-AL
# 6              Austin Adams   27    338         MLB-NL
# 7              Chance Adams   23    183         MLB-AL
# 8             Nathan Adcock   27   1345         MLB-NL
# 9               Tim Adleman   29    559         MLB-NL
# 10           Jeremy Affeldt   36   1275         MLB-NL
# 11            Andrew Albers   31    548         MLB-AL
# 12              Matt Albers   35    190  MLB-NL,MLB-AL
# 13          Al Alburquerque   31    548         MLB-AL
# 14           Raul Alcantara   24    549         MLB-AL
# 15          Sandy Alcantara   22    183         MLB-NL
# 16         Victor Alcantara   25    185         MLB-AL
# ...

# %%
big[big['Name'] == 'Justin Verlander']
# Out:
#                   Name  Age  #days     Lev               Tm    G   GS     W  \
# 1293  Justin Verlander   35    184  MLB-AL  Detroit,Houston  121  121  52.0
#
#          L  SV     IP    H    R   ER   BB   SO  HR  HBP   ERA    AB   2B  3B  \
# 1293  34.0 NaN  781.0  610  280  264  198  876  98   23  3.04  2869  115  13
#
#       IBB  GDP  SF  SB  CS  PO    BF    Pit   Str   StL   StS  GB/FB    LD  \
# 1293    6   30  22  20  13   3  3120  12805  0.67  0.17  0.12   0.33  0.25
#
#         PU   WHIP  BAbip   SO9  SO/W
# 1293  0.13  1.035  0.267  10.1  4.42

# %%
df = pd.DataFrame()

for idx, val in big.iterrows():
    try:
        first = big['Name'][idx].split()[0]
        last = big['Name'][idx].split()[1]
        data = playerid_lookup(last, first)
        df = df.append(data)
    except:
        continue
# Out:
# Gathering player lookup table. This may take a moment.
# Gathering player lookup table. This may take a moment.
# Gathering player lookup table. This may take a moment.
# Gathering player lookup table. This may take a moment.
# Gathering player lookup table. This may take a moment.
# Gathering player lookup table. This may take a moment.
# Gathering player lookup table. This may take a moment.
# Gathering player lookup table. This may take a moment.
# Gathering player lookup table. This may take a moment.
# Gathering player lookup table. This may take a moment.
# Gathering player lookup table. This may take a moment.
# Gathering player lookup table. This may take a moment.
# Gathering player lookup table. This may take a moment.
# Gathering player lookup table. This may take a moment.
# Gathering player lookup table. This may take a moment.
# Gathering player lookup table. This may take a moment.
# Gathering player lookup table. This may take a moment.
# ...

# %%
first = big['Name'][1].split()[0]
last = big['Name'][1].split()[1]

# %%
dat = playerid_lookup(last, first)
# Out:
# Gathering player lookup table. This may take a moment.

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-00cf07b74dcd> in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
cp = df.copy()

# %%
cp = cp.dropna()

# %%
cp.to_pickle('./pitcher_ids.pkl')

# %%
cp = cp[cp['mlb_played_last'] >= 2014]
cp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-939b46e03606> in <module>
# ----> 1 cp = cp[cp['mlb_played_last'] >= 2014]
#       2 cp
#
# NameError: name 'cp' is not defined

# %%
cp = cp.drop(cp['mlb_played_last'] < 2015)

# %%
len(big)
# Out:
# 1332

# %%
len(big['Name'].unique())
# Out:
# 1328

# %%
cp
# Out:
#           name_last name_first  key_mlbam key_retro  key_bbref  key_fangraphs  \
# 0           aardsma      david     430911  aardd001  aardsda01           1902
# 1              abad   fernando     472551  abadf001   abadfe01           4994
# 2              adam      jason     592094  adamj002   adamja01          11861
# 3             adams     austin     613534  adama002  adamsau02          13801
# 4             adams     austin     542866  adama001  adamsau01           7411
# 5             adams     austin     613534  adama002  adamsau02          13801
# 6             adams     austin     542866  adama001  adamsau01           7411
# 7             adams     chance     664856  adamc002  adamsch01          18135
# 8            adcock     nathan     502264  adcon001  adcocna01           3282
# 9           adleman        tim     534947  adlet001  adlemti01          10968
# 10          affeldt     jeremy     346793  affej001  affelje01            583
# ...

# %%
cp = cp.set_index(np.arange(len(cp)))

# %%
# Out:
#         name_last name_first  key_mlbam key_retro  key_bbref  key_fangraphs  \
# 0         aardsma      david     430911  aardd001  aardsda01           1902
# 8          adcock     nathan     502264  adcon001  adcocna01           3282
# 10        affeldt     jeremy     346793  affej001  affelje01            583
# 51       atchison      scott     425786  atchs001  atchisc01           2642
# 52         aumont  phillippe     518418  aumop001  aumonph01           5362
# 55        axelrod      dylan     518420  axeld001  axelrdy01           9303
# 58       badenhop      burke     488674  badeb001  badenbu01           9736
# 63          baker      scott     435044  bakes002  bakersc02           6176
# 64       balester     collin     444446  balec001  balesco01           6883
# 65        balfour      grant     346797  balfg001  balfogr01            718
# 77        barrett      aaron     502578  barra001  barreaa01          11243
# ...

# %%
cp[cp['mlb_played_first'] == 2019]
# Out:
# Empty DataFrame
# Columns: [name_last, name_first, key_mlbam, key_retro, key_bbref, key_fangraphs, mlb_played_first, mlb_played_last]
# Index: []

# %%
messy = pd.read_pickle('../pickles/messy_ids.pkl')

# %%
messy[messy['name_last'] == "tonkin"]
# Out:
# Empty DataFrame
# Columns: [name_last, name_first, key_mlbam, key_retro, key_bbref, key_fangraphs, mlb_played_first, mlb_played_last]
# Index: []

# %%
tonkin = playerid_lookup('Tonkin', 'Michael')
# Out:
# Gathering player lookup table. This may take a moment.

# %%
messy = messy.append(tonkin)

# %%
messy
# Out:
#        name_last name_first  key_mlbam key_retro  key_bbref  key_fangraphs  \
# 0        aardsma      david     430911  aardd001  aardsda01           1902
# 0           abad   fernando     472551  abadf001   abadfe01           4994
# 0           adam      jason     592094  adamj002   adamja01          11861
# 0          adams     austin     613534  adama002  adamsau02          13801
# 1          adams     austin         -1       NaN        NaN             -1
# 2          adams     austin         -1       NaN        NaN             -1
# 3          adams     austin     542866  adama001  adamsau01           7411
# 4          adams     austin         -1       NaN        NaN             -1
# 0          adams     austin     613534  adama002  adamsau02          13801
# 1          adams     austin         -1       NaN        NaN             -1
# 2          adams     austin         -1       NaN        NaN             -1
# ...

# %%
messy = messy.drop_duplicates(subset=['key_mlbam'])

# %%
messy = messy[messy['key_mlbam'] != -1]

# %%
messy.to_pickle('../pickles/messy_ids.pkl')

# %%
clean = messy.copy()
clean = clean.dropna()

# %%
clean = clean.set_index(np.arange(len(clean)))

# %%
clean.to_pickle('../pickles/clean_ids.pkl')

# %%
rg = clean.copy()
rg
# Out:
#          name_last name_first  key_mlbam key_retro  key_bbref  key_fangraphs  \
# 0          aardsma      david     430911  aardd001  aardsda01           1902
# 1             abad   fernando     472551  abadf001   abadfe01           4994
# 2             adam      jason     592094  adamj002   adamja01          11861
# 3            adams     austin     613534  adama002  adamsau02          13801
# 4            adams     austin     542866  adama001  adamsau01           7411
# 5            adams     chance     664856  adamc002  adamsch01          18135
# 6           adcock     nathan     502264  adcon001  adcocna01           3282
# 7          adleman        tim     534947  adlet001  adlemti01          10968
# 8          affeldt     jeremy     346793  affej001  affelje01            583
# 9           albers     andrew     452027  albea001  alberan01           7853
# 10          albers       matt     458006  albem001  alberma01           4300
# ...

# %%
rg[rg['mlb_played_last'] >= 2013]
# Out:
#          name_last name_first  key_mlbam key_retro  key_bbref  key_fangraphs  \
# 0          aardsma      david     430911  aardd001  aardsda01           1902
# 1             abad   fernando     472551  abadf001   abadfe01           4994
# 2             adam      jason     592094  adamj002   adamja01          11861
# 3            adams     austin     613534  adama002  adamsau02          13801
# 4            adams     austin     542866  adama001  adamsau01           7411
# 5            adams     chance     664856  adamc002  adamsch01          18135
# 6           adcock     nathan     502264  adcon001  adcocna01           3282
# 7          adleman        tim     534947  adlet001  adlemti01          10968
# 8          affeldt     jeremy     346793  affej001  affelje01            583
# 9           albers     andrew     452027  albea001  alberan01           7853
# 10          albers       matt     458006  albem001  alberma01           4300
# ...

# %%
def pitches_season(year):
    march = statcast('{}-03-01'.format(year), '{}-03-31'.format(year))
    april = statcast('{}-04-01'.format(year), '{}-04-30'.format(year))
    may = statcast('{}-05-01'.format(year), '{}-05-31'.format(year))
    june = statcast('{}-06-01'.format(year), '{}-06-30'.format(year))
    july = statcast('{}-07-01'.format(year), '{}-07-31'.format(year))
    aug = statcast('{}-08-01'.format(year), '{}-08-31'.format(year))
    sept = statcast('{}-09-01'.format(year), '{}-09-30'.format(year))
    octo = statcast('{}-10-01'.format(year), '{}-10-31'.format(year))
    nov = statcast('{}-11-01'.format(year), '{}-11-30'.format(year))

    total = pd.concat([march,april,may,june,july,aug,sept,octo,nov])
    print(len(total))
    copy = total.dropna(subset=['pitch_type'])
    print(len(copy))
    copy['game_date'] = pd.to_datetime(copy['game_date'])

    return copy

# %%
sc_18 = pitches_season(2018)
# Out:
# This is a large query, it may take a moment to complete
# Completed sub-query from 2018-03-01 to 2018-03-31
# This is a large query, it may take a moment to complete
# Completed sub-query from 2018-04-01 to 2018-04-06
# Completed sub-query from 2018-04-07 to 2018-04-12
# Completed sub-query from 2018-04-13 to 2018-04-18
# Completed sub-query from 2018-04-19 to 2018-04-24
# Completed sub-query from 2018-04-25 to 2018-04-30
# This is a large query, it may take a moment to complete
# Completed sub-query from 2018-05-01 to 2018-05-06
# Completed sub-query from 2018-05-07 to 2018-05-12
# Completed sub-query from 2018-05-13 to 2018-05-18
# Completed sub-query from 2018-05-19 to 2018-05-24
# Completed sub-query from 2018-05-25 to 2018-05-30
# Completed sub-query from 2018-05-31 to 2018-05-31
# This is a large query, it may take a moment to complete
# Completed sub-query from 2018-06-01 to 2018-06-06
# Completed sub-query from 2018-06-07 to 2018-06-12
# ...

# %%
sc_18
# Out:
#       index pitch_type  game_date  release_speed  release_pos_x  \
# 0        27         SI 2018-03-31           95.4        -3.3271
# 1        29         SI 2018-03-31           94.9        -3.4313
# 2        31         SI 2018-03-31           94.1        -3.3021
# 3        34         CU 2018-03-31           80.4        -3.1142
# 4        37         FF 2018-03-31           94.8         0.5153
# 5        40         FF 2018-03-31           96.2         0.8218
# 6        43         FF 2018-03-31           97.1         0.9970
# 7        46         FF 2018-03-31           95.4         1.0840
# 8        49         SL 2018-03-31           84.8         1.4288
# 9        52         SL 2018-03-31           84.9         1.3440
# 10       55         FF 2018-03-31           94.6         1.0634
# 11       58         FF 2018-03-31           96.8         0.8682
# 12       67         FF 2018-03-31           95.8         0.8474
# 13       69         FF 2018-03-31           93.6         1.0592
# ...

# %%
sc_18.head()
# Out:
#   index pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 0    27         SI 2018-03-31           95.4        -3.3271         4.8984
# 1    29         SI 2018-03-31           94.9        -3.4313         4.7602
# 2    31         SI 2018-03-31           94.1        -3.3021         4.8853
# 3    34         CU 2018-03-31           80.4        -3.1142         5.0533
# 4    37         FF 2018-03-31           94.8         0.5153         6.3881
#
#    player_name    batter   pitcher     events    description  spin_dir  \
# 0  Trevor Gott  594807.0  641627.0  field_out  hit_into_play       NaN
# 1  Trevor Gott  594807.0  641627.0        NaN           foul       NaN
# 2  Trevor Gott  594807.0  641627.0        NaN           ball       NaN
# 3  Trevor Gott  594807.0  641627.0        NaN  called_strike       NaN
# 4  Enny Romero  594988.0  544836.0  field_out  hit_into_play       NaN
#
#    spin_rate_deprecated  break_angle_deprecated  break_length_deprecated  \
# ...

# %%
engine = create_engine('postgresql+psycopg2://taylorphillips@localhost/statcast')

sc_18.to_sql('pitches', engine, if_exists='append')

# %%
fg = pitching_stats(2018, end_season=2018, league='all', qual=0, ind=1)

# %%
fg.columns.tolist()
# Out:
# ['Season',
#  'Name',
#  'Team',
#  'Age',
#  'W',
#  'L',
#  'ERA',
#  'WAR',
#  'G',
#  'GS',
#  'CG',
#  'ShO',
#  'SV',
#  'BS',
#  'IP',
#  'TBF',
#  'H',
#  'R',
#  'ER',
#  'HR',
#  'BB',
#  'IBB',
#  'HBP',
#  'WP',
#  'BK',
#  'SO',
#  'GB',
#  'FB',
#  'LD',
#  'IFFB',
#  'Balls',
#  'Strikes',
#  'Pitches',
#  'RS',
#  'IFH',
#  'BU',
#  'BUH',
#  'K/9',
#  'BB/9',
#  'K/BB',
#  'H/9',
#  'HR/9',
#  'AVG',
#  'WHIP',
#  'BABIP',
#  'LOB%',
#  'FIP',
#  'GB/FB',
#  'LD%',
#  'GB%',
#  'IFFB%',
#  'HR/FB',
#  'IFH%',
#  'BUH%',
#  'Starting',
#  'Start-IP',
#  'Relieving',
#  'Relief-IP',
#  'RAR',
#  'Dollars',
#  'tERA',
#  'xFIP',
#  'WPA',
#  '-WPA',
#  '+WPA',
#  'RE24',
#  'REW',
#  'pLI',
#  'inLI',
#  'gmLI',
#  'exLI',
#  'Pulls',
#  'WPA/LI',
#  'Clutch',
#  'FB%',
#  'FBv',
#  'SL%',
#  'SLv',
#  'CT%',
#  'CTv',
#  'CB%',
#  'CBv',
#  'CH%',
#  'CHv',
#  'SF%',
#  'SFv',
#  'KN%',
#  'KNv',
#  'XX%',
#  'PO%',
#  'wFB',
#  'wSL',
#  'wCT',
#  'wCB',
#  'wCH',
# ...

# %%
fg
# Out:
#      Season                 Name          Team   Age     W     L    ERA  WAR  \
# 48   2018.0         Jacob deGrom          Mets  30.0  10.0   9.0   1.70  9.0
# 99   2018.0         Max Scherzer     Nationals  33.0  18.0   7.0   2.53  7.4
# 98   2018.0     Justin Verlander        Astros  35.0  16.0   9.0   2.52  6.7
# 64   2018.0           Chris Sale       Red Sox  29.0  12.0   4.0   2.11  6.2
# 140  2018.0          Gerrit Cole        Astros  27.0  15.0   5.0   2.88  6.0
# 179  2018.0       Patrick Corbin  Diamondbacks  28.0  11.0   7.0   3.15  5.9
# 71   2018.0         Trevor Bauer       Indians  27.0  12.0   6.0   2.21  5.8
# 143  2018.0         Corey Kluber       Indians  32.0  20.0   7.0   2.89  5.5
# 224  2018.0        Luis Severino       Yankees  24.0  19.0   8.0   3.39  5.5
# 81   2018.0           Aaron Nola      Phillies  25.0  17.0   6.0   2.37  5.4
# 221  2018.0      Carlos Carrasco       Indians  31.0  17.0  10.0   3.38  5.2
# ...

# %%
bwar = bwar_pitch(return_all=True)

# %%
bwar
# Out:
#            name_common   age    mlb_ID  player_ID  year_ID team_ID  stint_ID  \
# 0        David Aardsma  22.0  430911.0  aardsda01     2004     SFG         1
# 1        David Aardsma  24.0  430911.0  aardsda01     2006     CHC         1
# 2        David Aardsma  25.0  430911.0  aardsda01     2007     CHW         1
# 3        David Aardsma  26.0  430911.0  aardsda01     2008     BOS         1
# 4        David Aardsma  27.0  430911.0  aardsda01     2009     SEA         1
# 5        David Aardsma  28.0  430911.0  aardsda01     2010     SEA         1
# 6        David Aardsma  30.0  430911.0  aardsda01     2012     NYY         1
# 7        David Aardsma  31.0  430911.0  aardsda01     2013     NYM         1
# 8        David Aardsma  33.0  430911.0  aardsda01     2015     ATL         1
# 9             Don Aase  22.0  110003.0   aasedo01     1977     BOS         1
# 10            Don Aase  23.0  110003.0   aasedo01     1978     CAL         1
# ...
