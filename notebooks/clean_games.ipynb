# %%
import pandas as pd
import numpy as np
import pickle
pd.set_option('display.max_columns', 500)
from pybaseball import *

# %%
pwd
# Out:
# '/Users/taylorphillips/galvanize/mlb/mlb_injuries/notebooks'

# %%
throws = pd.read_pickle('/Users/taylorphillips/galvanize/mlb/data/2018_throws.pkl')

# %%
throws
# Out:
#       index pitch_type  game_date  release_speed  release_pos_x  \
# 0        27         SI 2018-03-31           95.4        -3.3271
# 1        29         SI 2018-03-31           94.9        -3.4313
# 2        31         SI 2018-03-31           94.1        -3.3021
# 3        34         CU 2018-03-31           80.4        -3.1142
# 4        37         FF 2018-03-31           94.8         0.5153
# 5        40         FF 2018-03-31           96.2         0.8218
# 6        43         FF 2018-03-31           97.1         0.9970
# 7        46         FF 2018-03-31           95.4         1.0840
# 8        49         SL 2018-03-31           84.8         1.4288
# 9        52         SL 2018-03-31           84.9         1.3440
# 10       55         FF 2018-03-31           94.6         1.0634
# 11       58         FF 2018-03-31           96.8         0.8682
# 12       67         FF 2018-03-31           95.8         0.8474
# 13       69         FF 2018-03-31           93.6         1.0592
# ...

# %%
throws.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 731207 entries, 0 to 10546
# Data columns (total 90 columns):
# index                              731207 non-null object
# pitch_type                         727510 non-null object
# game_date                          731207 non-null datetime64[ns]
# release_speed                      727522 non-null float64
# release_pos_x                      727371 non-null float64
# release_pos_z                      727371 non-null float64
# player_name                        731207 non-null object
# batter                             731207 non-null float64
# pitcher                            731207 non-null float64
# events                             187162 non-null object
# description                        731207 non-null object
# spin_dir                           0 non-null float64
# spin_rate_deprecated               0 non-null float64
# break_angle_deprecated             0 non-null float64
# ...

# %%
games = pd.read_pickle('../pickles/2018_games.pkl')
games
# Out:
#                     name  age  #days     lev             tm  g  gs    w    l  \
# 0            Matt Albers   35    368  MLB-NL      Milwaukee  1   0  NaN  NaN
# 1          Dan Altavilla   25    368  MLB-AL        Seattle  1   0  NaN  NaN
# 2           Jose Alvarez   29    368  MLB-AL    Los Angeles  1   0  NaN  NaN
# 3         Chase Anderson   30    368  MLB-NL      Milwaukee  1   1  NaN  NaN
# 4           Chris Archer   29    368  MLB-AL      Tampa Bay  1   1  NaN  NaN
# 5            Luis Avilan   28    368  MLB-AL        Chicago  1   0  NaN  NaN
# 6            John Axford   35    368  MLB-AL        Toronto  1   0  NaN  NaN
# 7           Danny Barnes   28    368  MLB-AL        Toronto  1   0  NaN  NaN
# 8           Jacob Barnes   28    368  MLB-NL      Milwaukee  1   0  NaN  NaN
# 9            Matt Barnes   28    368  MLB-AL         Boston  1   0  NaN  NaN
# 10         Cam Bedrosian   26    368  MLB-AL    Los Angeles  1   0  NaN  NaN
# ...

# %%
# jv = games[games['Name'] == 'Justin Verlander']

# %%
# games['date'] = pd.to_datetime(games['date'], format="%Y/%m/%d")

# %%
# games.columns = [x.lower().strip() for x in games.columns]

# %%
# games = games.set_index(np.arange(len(games)))

# %%
cm = games[games['name'] == 'Charlie Morton']
cm
# Out:
#                  name  age  #days     lev       tm  g  gs    w    l  sv   ip  \
# 529    Charlie Morton   34    364  MLB-AL  Houston  1   1  1.0  NaN NaN  6.0
# 1195   Charlie Morton   34    358  MLB-AL  Houston  1   1  1.0  NaN NaN  6.0
# 1859   Charlie Morton   34    352  MLB-AL  Houston  1   1  NaN  NaN NaN  6.0
# 2351   Charlie Morton   34    347  MLB-AL  Houston  1   1  1.0  NaN NaN  7.0
# 2883   Charlie Morton   34    342  MLB-AL  Houston  1   1  NaN  NaN NaN  4.0
# 3598   Charlie Morton   34    336  MLB-AL  Houston  1   1  1.0  NaN NaN  7.2
# 4179   Charlie Morton   34    331  MLB-AL  Houston  1   1  NaN  NaN NaN  5.0
# 4959   Charlie Morton   34    324  MLB-AL  Houston  1   1  1.0  NaN NaN  7.0
# 5577   Charlie Morton   34    318  MLB-AL  Houston  1   1  1.0  NaN NaN  7.0
# 6220   Charlie Morton   34    312  MLB-AL  Houston  1   1  1.0  NaN NaN  6.0
# 6848   Charlie Morton   34    307  MLB-AL  Houston  1   1  NaN  NaN NaN  6.0
# ...

# %%
dl_18 = pd.read_pickle('../pickles/2018_DL.pkl')
dl_18[dl_18['player'] == 'charlie morton']
# Out:
#             player posititon team    injury  days  year list  startdate  \
# 13  charlie morton        SP   TB  Shoulder    11  2018   10 2018-08-29
#
#    enddate moneyearned
# 13     9/8      413974

# %%
dl_18
# Out:
#                  player posititon team                injury  days  year list  \
# 0          eric hanhold         P  NYM               Oblique     7  2018   60
# 1        michael fulmer        SP  DET          Knee/Oblique    47  2018   60
# 2         clay buchholz        SP  TOR         Elbow/Oblique    47  2018   60
# 3           luiz gohara        SP  ATL        Shoulder/Ankle    49  2018   60
# 4        michael kopech        SP  CHW      Elbow Tommy John    24  2018   60
# 5           keury mella        RP  CIN               Oblique    28  2018   60
# 6        joseph biagini        RP  TOR               Oblique    11  2018   10
# 7           jose mujica         P   TB           Undisclosed    29  2018   60
# 8         brock stewart        SP  LAD               Oblique    30  2018   60
# 9           pablo lopez        SP  MIA              Shoulder    31  2018   60
# 10     kendall graveman        SP  CHC      Elbow Tommy John    31  2018   60
# ...

# %%
# dl_18['startdate'] = dl_18['startdate'].str.strip()

# %%
# dl_18['startdate'] = dl_18['startdate'].str.replace('/','-')

# %%
# dl_18['startdate'][0] + '-' + str(dl_18['year'][0])

# %%
# for idx, val in dl_18.iterrows():
#     dl_18['startdate'][idx] = dl_18['startdate'][idx] + '-' + str(dl_18['year'][idx])

# %%
# dl_18['startdate'] = pd.to_datetime(dl_18['startdate'])

# %%
# dl_18['startdate'] = pd.to_datetime(dl_18['startdate'], format="%Y/%m/%d")

# %%
inj_date = dl_18[dl_18['player'] == 'charlie morton'].values[0][-3]
inj_date
# Out:
# Timestamp('2018-08-29 00:00:00')

# %%
inj_game = cm[cm['date'] < inj_date][-5:]
inj_game
# Out:
#                  name  age  #days     lev       tm  g  gs    w    l  sv   ip  \
# 14281  Charlie Morton   34    238  MLB-AL  Houston  1   1  NaN  NaN NaN  7.0
# 14839  Charlie Morton   34    233  MLB-AL  Houston  1   1  NaN  1.0 NaN  6.0
# 15514  Charlie Morton   34    227  MLB-AL  Houston  1   1  NaN  NaN NaN  5.0
# 16111  Charlie Morton   34    222  MLB-AL  Houston  1   1  1.0  NaN NaN  5.0
# 16764  Charlie Morton   34    216  MLB-AL  Houston  1   1  NaN  NaN NaN  4.2
#
#        h  r  er  bb  so  hr  hbp    era  ab  2b  3b  ibb  gdp  sf  sb  cs  po  \
# 14281  3  1   1   3   8   1    0   1.29  22   1   0    0    1   0   0   0   0
# 14839  7  3   3   1   4   0    1   4.50  21   2   1    0    3   0   0   0   0
# 15514  4  2   0   2   4   0    0   0.00  19   1   0    0    1   0   0   0   0
# 16111  7  6   6   1   7   1    2  10.80  22   3   0    0    0   0   0   0   0
# 16764  3  3   3   4   3   1    1   5.79  17   0   0    0    0   0   1   0   0
#
# ...

# %%
str(inj_game.values[0][-1]).split()[0]
# Out:
# '2018-08-28'

# %%
games
# Out:
#                     name  age  #days     lev             tm  g  gs    w    l  \
# 0            Matt Albers   35    368  MLB-NL      Milwaukee  1   0  NaN  NaN
# 1          Dan Altavilla   25    368  MLB-AL        Seattle  1   0  NaN  NaN
# 2           Jose Alvarez   29    368  MLB-AL    Los Angeles  1   0  NaN  NaN
# 3         Chase Anderson   30    368  MLB-NL      Milwaukee  1   1  NaN  NaN
# 4           Chris Archer   29    368  MLB-AL      Tampa Bay  1   1  NaN  NaN
# 5            Luis Avilan   28    368  MLB-AL        Chicago  1   0  NaN  NaN
# 6            John Axford   35    368  MLB-AL        Toronto  1   0  NaN  NaN
# 7           Danny Barnes   28    368  MLB-AL        Toronto  1   0  NaN  NaN
# 8           Jacob Barnes   28    368  MLB-NL      Milwaukee  1   0  NaN  NaN
# 9            Matt Barnes   28    368  MLB-AL         Boston  1   0  NaN  NaN
# 10         Cam Bedrosian   26    368  MLB-AL    Los Angeles  1   0  NaN  NaN
# ...
